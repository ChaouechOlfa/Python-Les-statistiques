# %%
#chapiterII: Comprendre la statistique descriptive:

# %%
import pandas as pd

# %%
#Afficher la version de pandas installée sur notre système

# %%
print("la version pandas installée est:", pd.__version__)
# Out:
# la version pandas installée est: 1.5.3

# %%
#Chargement des données
maDataFrame=pd.read_csv('Data/ozone.csv')

# %%
maDataFrame
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG
# 0    -0.64350
# 1    -0.04996
# 2    -0.12832
# 3    -0.34516
# ...

# %%
maDataFrame.head(5)
# Out:
#    JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  VentANG
# 0     1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000 -0.64350
# 1     1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100 -0.04996
# 2     0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771 -0.12832
# 3     0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578 -0.34516
# 4     0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791 -0.41822

# %%
maDataFrame.tail(5)
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG
# 1036 -0.20964
# 1037 -0.62880
# 1038  0.12435
# 1039  0.00000
# 1040  0.04345

# %%
maDataFrame_excel=pd.read_excel('Data/ozone.xlsx')

# %%
maDataFrame_excel
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG
# 0    -0.64350
# 1    -0.04996
# 2    -0.12832
# 3    -0.34516
# ...

# %%
#Sauvegardées les données dans un fichier CSV en utilisant la méthode to_csv de pandas

# %%
maDataFrame_excel_to_csv= maDataFrame_excel.to_csv('Data/output/ozone.csv',index=False)

# %%
maDataFrame.columns
# Out:
# Index(['JOUR', 'O3obs', 'MOCAGE', 'TEMPE', 'RMH2O', 'NO2', 'NO', 'STATION',
#        'VentMOD', 'VentANG'],
#       dtype='object')

# %%
maDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   JOUR     1041 non-null   int64
#  1   O3obs    1041 non-null   int64
#  2   MOCAGE   1041 non-null   float64
#  3   TEMPE    1041 non-null   float64
#  4   RMH2O    1041 non-null   float64
#  5   NO2      1041 non-null   float64
#  6   NO       1041 non-null   float64
#  7   STATION  1041 non-null   object
#  8   VentMOD  1041 non-null   float64
#  9   VentANG  1041 non-null   float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 81.5+ KB

# %%
maDataFrame['O3obs']
# Out:
# 0        91
# 1       100
# 2        82
# 3        94
# 4       107
#        ...
# 1036    116
# 1037     60
# 1038     74
# 1039    121
# 1040     93
# Name: O3obs, Length: 1041, dtype: int64

# %%
#Pour accéder aux données d'une variable nous pouvons utiliser aussi
maDataFrame.O3obs
# Out:
# 0        91
# 1       100
# 2        82
# 3        94
# 4       107
#        ...
# 1036    116
# 1037     60
# 1038     74
# 1039    121
# 1040     93
# Name: O3obs, Length: 1041, dtype: int64

# %%
maDataFrame=pd.read_csv('Data/ecoles-creches-idf.csv')

# %%
maDataFrame
# Out:
#              ID                                                nom  \
# 0      0750026W  L'Enseignement par petits groupes (Ecole secon...
# 1      0750106H  Ecole technologique privée CCIP Centre des For...
# 2      0750132L        Ecole primaire privée Notre-Dame-Saint Roch
# 3      0750136R                Ecole primaire privée Saint-Sauveur
# 4      0750138T   Ecole primaire privée Sainte Geneviève du Marais
# ...         ...                                                ...
# 12525     12192                              Les p tits Cressonets
# 12526     12193                                       Les lucioles
# 12527     12194                                    Les coccinelles
# 12528     12195                                              Soyer
# 12529     12196                                     Emile Bergerat
#
#        departement              ville     CP        type   NO2_2012  \
# 0               75           Paris 15  75015  secondaire  41.316912
# ...

# %%
maDataFrameMelt=maDataFrame.melt(['ID','nom','departement','ville','CP','type'],['NO2_2012','NO2_2013','NO2_2014','NO2_2015','NO2_2016','NO2_2017','PM10_2012','PM10_2013','PM10_2014','PM10_2015','PM10_2016','PM10_2017','PM25_2012','PM25_2013','PM25_2014','PM25_2015','PM25_2016','PM25_2017'],'Polluant-Année','Valeur')

# %%
maDataFrameMelt
# Out:
#               ID                                                nom  \
# 0       0750026W  L'Enseignement par petits groupes (Ecole secon...
# 1       0750106H  Ecole technologique privée CCIP Centre des For...
# 2       0750132L        Ecole primaire privée Notre-Dame-Saint Roch
# 3       0750136R                Ecole primaire privée Saint-Sauveur
# 4       0750138T   Ecole primaire privée Sainte Geneviève du Marais
# ...          ...                                                ...
# 225535     12192                              Les p tits Cressonets
# 225536     12193                                       Les lucioles
# 225537     12194                                    Les coccinelles
# 225538     12195                                              Soyer
# 225539     12196                                     Emile Bergerat
#
#         departement              ville     CP        type Polluant-Année  \
# 0                75           Paris 15  75015  secondaire       NO2_2012
# ...
